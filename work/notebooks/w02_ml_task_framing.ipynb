# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/forhadmia231/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My Lane as an ML Task
#
# Task Type:
# Classification
#
# The goal is to predict whether a content item will perform well based on historical features.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# # 2. Target or Proxy
#
# Target:
#
# High Performance
#
# Proxy Target:
#
# A binary column representing whether a content item performs well.
#
# Example:
#
# 1 = High Performing
#
# 0 = Low Performing

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Success Metric
#
# Metric:
# F1 Score
#
# Reason:
# The dataset may contain more low-performing than high-performing content.
# F1 Score balances precision and recall.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# One row represents one content item.

# %%
# !pip install -q datasets

from datasets import load_dataset

ds = load_dataset("FlyRank/internship-starter")

df = ds["train"].to_pandas()

df.head()
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# content_refresh_anonymized.csv:   0%|          | 0.00/8.23M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/30000 [00:00<?, ? examples/s]
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# ...

# %% [markdown]
# A fixed rule cannot capture complex relationships among multiple features.
#
# Machine learning can learn patterns from historical data and generalize to unseen content, making predictions more accurate than manually written rules.

# %%
df.info()
df.columns.tolist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 53 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   content_id                    30000 non-null  object
#  1   client_id                     30000 non-null  object
#  2   search_volume                 27532 non-null  float64
#  3   competition                   27532 non-null  float64
#  4   competition_level             27390 non-null  object
#  5   cpc                           27532 non-null  float64
#  6   content_type                  30000 non-null  object
#  7   main_intent                   27626 non-null  object
#  8   word_count                    22301 non-null  float64
#  9   char_count                    22301 non-null  float64
#  10  provider_used                 8562 non-null   object
#  11  model_used                    24267 non-null  object
# ...

# %% [markdown]
# # 6. Self Check
#
# ✔ ML task identified
#
# ✔ Target column selected
#
# ✔ Success metric defined
#
# ✔ Unit of analysis explained
#
# ✔ Dataset loaded
#
# ✔ ML justification provided
#
# ✔ Real business action explained

# %%
df.head(10)
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
# 5  content_d4084a4bc775  client_f369cb89fc          720.0         1.00
# 6  content_9a34b442b552  client_8722616204            0.0         0.00
# 7  content_a63219c6e95a  client_19581e27de          590.0         0.44
# 8  content_5e6c160719bc  client_6208ef0f77            0.0         0.00
# 9  content_c27558df2b0c  client_19581e27de            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# ...

# %% [markdown]
# Create a Sample Target Column
#
# Note: The actual column depends on the dataset. First, inspect the available columns.

# %%
df.head()
df[['content_id','content_type','main_intent','health_score','is_initial_refresh_candidate']].head()
# Out:
#              content_id     content_type    main_intent  health_score  \
# 0  content_304f48230142  keyword article  transactional            50
# 1  content_a1fb4e703a9e  keyword article  informational            40
# 2  content_9aa793d4d895  keyword article  informational            40
# 3  content_331d6c4de07b  keyword article     commercial            60
# 4  content_d99b7a2d90ca  keyword article  informational            40
#
#   is_initial_refresh_candidate
# 0                         True
# 1                         True
# 2                        False
# 3                         True
# 4                        False

# %%
import matplotlib.pyplot as plt

df['is_initial_refresh_candidate'].value_counts().plot(kind='bar')

plt.title("Target Variable Distribution")
plt.xlabel("Refresh Candidate")
plt.ylabel("Count")
plt.show()
